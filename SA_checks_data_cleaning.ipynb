# %%
import pandas as pd
import numpy as np
import warnings

# %% [markdown]
# <h3><b>Load data</b></h3>

# %%
train= pd.read_csv('./Train.csv')
test = pd.read_csv('./Test.csv')

# %%
train.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
test.head()
# Out:
#   country  year       uniqueid location_type cellphone_access  household_size  \
# 0   Kenya  2018  uniqueid_6056         Urban              Yes               3
# 1   Kenya  2018  uniqueid_6060         Urban              Yes               7
# 2   Kenya  2018  uniqueid_6065         Rural               No               3
# 3   Kenya  2018  uniqueid_6072         Rural               No               6
# 4   Kenya  2018  uniqueid_6073         Urban               No               3
#
#    age_of_respondent gender_of_respondent relationship_with_head  \
# 0                 30                 Male      Head of Household
# 1                 51                 Male      Head of Household
# 2                 77               Female                 Parent
# 3                 39               Female      Head of Household
# 4                 16                 Male                  Child
#
#             marital_status                  education_level  \
# ...

# %%
train.shape
# Out:
# (23524, 13)

# %%
test.shape
# Out:
# (10086, 12)

# %%
train.describe(include=[np.number])
# Out:
#                year  household_size  age_of_respondent
# count  23524.000000    23524.000000       23524.000000
# mean    2016.975939        3.797483          38.805220
# std        0.847371        2.227613          16.520569
# min     2016.000000        1.000000          16.000000
# 25%     2016.000000        2.000000          26.000000
# 50%     2017.000000        3.000000          35.000000
# 75%     2018.000000        5.000000          49.000000
# max     2018.000000       21.000000         100.000000

# %%
train.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'bank_account', 'location_type',
#        'cellphone_access', 'household_size', 'age_of_respondent',
#        'gender_of_respondent', 'relationship_with_head', 'marital_status',
#        'education_level', 'job_type'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'location_type', 'cellphone_access',
#        'household_size', 'age_of_respondent', 'gender_of_respondent',
#        'relationship_with_head', 'marital_status', 'education_level',
#        'job_type'],
#       dtype='object')

# %% [markdown]
# <h3><b>Data Checks</b></h3>

# %% [markdown]
# <h4></b>Check missing values, duplicates ,</h3></b>

# %%
clean_data= train.copy()

# %%
check_missing_values= clean_data.isnull().any(axis=1)
mising_values= clean_data[check_missing_values]
mising_values
# Out:
# Empty DataFrame
# Columns: [country, year, uniqueid, bank_account, location_type, cellphone_access, household_size, age_of_respondent, gender_of_respondent, relationship_with_head, marital_status, education_level, job_type]
# Index: []

# %%
clean_data_test= test.copy()

# %%
check_missing_values_test= clean_data_test.isnull().any(axis=1)
check_missing_values_test= clean_data_test[check_missing_values]
check_missing_values_test
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18976\791183011.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   check_missing_values_test= clean_data_test[check_missing_values]
# Empty DataFrame
# Columns: [country, year, uniqueid, location_type, cellphone_access, household_size, age_of_respondent, gender_of_respondent, relationship_with_head, marital_status, education_level, job_type]
# Index: []

# %%
clean_data= clean_data[~check_missing_values]
clean_data.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
clean_data_test.head()
# Out:
#   country  year       uniqueid location_type cellphone_access  household_size  \
# 0   Kenya  2018  uniqueid_6056         Urban              Yes               3
# 1   Kenya  2018  uniqueid_6060         Urban              Yes               7
# 2   Kenya  2018  uniqueid_6065         Rural               No               3
# 3   Kenya  2018  uniqueid_6072         Rural               No               6
# 4   Kenya  2018  uniqueid_6073         Urban               No               3
#
#    age_of_respondent gender_of_respondent relationship_with_head  \
# 0                 30                 Male      Head of Household
# 1                 51                 Male      Head of Household
# 2                 77               Female                 Parent
# 3                 39               Female      Head of Household
# 4                 16                 Male                  Child
#
#             marital_status                  education_level  \
# ...

# %%
mising_values.empty
# Out:
# True

# %% [markdown]
# <h3><b>check duplicates uniqued </b></h3>

# %%
check_duplicates = clean_data['uniqueid'].duplicated()
dirt_data = clean_data[check_duplicates]
dirt_data
# Out:
#       country  year       uniqueid bank_account location_type  \
# 6068   Rwanda  2016     uniqueid_1           No         Urban
# 6069   Rwanda  2016     uniqueid_2          Yes         Urban
# 6070   Rwanda  2016     uniqueid_3           No         Rural
# 6071   Rwanda  2016     uniqueid_4          Yes         Urban
# 6072   Rwanda  2016     uniqueid_5           No         Rural
# ...       ...   ...            ...          ...           ...
# 23519  Uganda  2018  uniqueid_2113           No         Rural
# 23520  Uganda  2018  uniqueid_2114           No         Rural
# 23521  Uganda  2018  uniqueid_2115           No         Rural
# 23522  Uganda  2018  uniqueid_2116           No         Urban
# 23523  Uganda  2018  uniqueid_2117           No         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 6068               Yes               7                 18
# 6069               Yes               4                 26
# ...

# %%
clean_data.shape
# Out:
# (23524, 13)

# %%
duplicates_uni= clean_data[check_duplicates]
duplicates_uni
# Out:
#       country  year       uniqueid bank_account location_type  \
# 6068   Rwanda  2016     uniqueid_1           No         Urban
# 6069   Rwanda  2016     uniqueid_2          Yes         Urban
# 6070   Rwanda  2016     uniqueid_3           No         Rural
# 6071   Rwanda  2016     uniqueid_4          Yes         Urban
# 6072   Rwanda  2016     uniqueid_5           No         Rural
# ...       ...   ...            ...          ...           ...
# 23519  Uganda  2018  uniqueid_2113           No         Rural
# 23520  Uganda  2018  uniqueid_2114           No         Rural
# 23521  Uganda  2018  uniqueid_2115           No         Rural
# 23522  Uganda  2018  uniqueid_2116           No         Urban
# 23523  Uganda  2018  uniqueid_2117           No         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 6068               Yes               7                 18
# 6069               Yes               4                 26
# ...

# %%
check_duplicates_test = clean_data_test['uniqueid'].duplicated()
dirt_test = clean_data_test[~check_duplicates]
clean_data_test.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18976\4109099924.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dirt_test = clean_data_test[~check_duplicates]
#   country  year       uniqueid location_type cellphone_access  household_size  \
# 0   Kenya  2018  uniqueid_6056         Urban              Yes               3
# 1   Kenya  2018  uniqueid_6060         Urban              Yes               7
# 2   Kenya  2018  uniqueid_6065         Rural               No               3
# 3   Kenya  2018  uniqueid_6072         Rural               No               6
# 4   Kenya  2018  uniqueid_6073         Urban               No               3
#
#    age_of_respondent gender_of_respondent relationship_with_head  \
# 0                 30                 Male      Head of Household
# 1                 51                 Male      Head of Household
# 2                 77               Female                 Parent
# ...

# %%
duplicates_uni_test =clean_data_test[~check_duplicates_test]

# %%
clean_data_test.shape
# Out:
# (6068, 12)

# %%
train.duplicated().any(axis=0)
# Out:
# False

# %%
train=clean_data.copy()
test=clean_data_test.copy()

# %%
test.head()
# Out:
#   country  year       uniqueid location_type cellphone_access  household_size  \
# 0   Kenya  2018  uniqueid_6056         Urban              Yes               3
# 1   Kenya  2018  uniqueid_6060         Urban              Yes               7
# 2   Kenya  2018  uniqueid_6065         Rural               No               3
# 3   Kenya  2018  uniqueid_6072         Rural               No               6
# 4   Kenya  2018  uniqueid_6073         Urban               No               3
#
#    age_of_respondent gender_of_respondent relationship_with_head  \
# 0                 30                 Male      Head of Household
# 1                 51                 Male      Head of Household
# 2                 77               Female                 Parent
# 3                 39               Female      Head of Household
# 4                 16                 Male                  Child
#
#             marital_status                  education_level  \
# ...

# %%
test.shape
# Out:
# (6068, 12)

# %%
train.shape
# Out:
# (8735, 13)
